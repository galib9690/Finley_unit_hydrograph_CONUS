# %%
#This program is designed to automate the URL generation and site collection on USGS' website for all of the USA states
#
# When generating URLs using the website, for the purposes of this project, instantaneous data, stream watersheds,
# and a maximum of 40 square miles are constant.
#
# https://waterservices.usgs.gov/nwis/site/?format=rdb&stateCd=ia&startDT=2001-01-01&endDT=2001-12-31&siteOutput=expanded&siteType=ST&siteStatus=all&hasDataTypeCd=iv&drainAreaMax=40
#
# Version 1.3, years are also constant as 2000-2020.

# %%
# Import necessary modules
import urllib.request
import os
import shutil
import pandas as pd

# Directory setup
Direct = "C:/Users/mgalib/Box/Finley_UH_work/Data/"

# List of valid state codes
states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA",
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD",
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ",
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC",
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

# Define years
years = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
         '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
         '2018', '2019', '2020']

print('Sites will be retrieved from 2000 through 2020.')

# Loop through each state in the states list
for state in states:
    # Create state results directories if they do not already exist
    state_text_dir = Direct + state + '/text'
    state_sites_dir = Direct + state + '/sites'
    
    if not os.path.exists(state_text_dir):
        os.makedirs(state_text_dir)
    if not os.path.exists(state_sites_dir):
        os.makedirs(state_sites_dir)

    # Loop through each year
    for year in years:
        file_name = f'{state}_{year}.txt'
        sites_text = f'{state}_{year}_sites.txt'
        text_file_path = os.path.join(state_text_dir, file_name)
        sites_file_path = os.path.join(state_sites_dir, sites_text)

        # Check if the data for this state and year has already been downloaded
        if os.path.exists(text_file_path) and os.path.exists(sites_file_path):
            print(f'Data for {state} in {year} already downloaded. Skipping.')
            continue

        try:
            # Create URL for the given state and year
            url = f'https://waterservices.usgs.gov/nwis/site/?format=rdb&stateCd={state}&startDT={year}-01-01&endDT={year}-12-31&siteOutput=expanded&siteType=ST&siteStatus=all&hasDataTypeCd=iv&drainAreaMax=40'
            
            # Download the text file
            urllib.request.urlretrieve(url, text_file_path)

            # Read the text file and extract sites
            with open(text_file_path, 'r') as file:
                lines = file.readlines()
                sites = [line[5:line.index('\t', 8)] for line in lines if line[0] != '#' and lines.index(line) > 2]

            # Convert the sites list to a DataFrame and save as a text file
            sites_df = pd.DataFrame(sites)
            sites_df.to_csv(sites_file_path, sep='\t', index=False, header=None)

        except urllib.error.HTTPError as e:
            print(f'Failed to download data for {state} in {year}: {e}')

print('Site retrieval and storage is complete for all states.')
# Out:
# Sites will be retrieved from 2000 through 2020.
# Data for AL in 2000 already downloaded. Skipping.
# Data for AL in 2001 already downloaded. Skipping.
# Data for AL in 2002 already downloaded. Skipping.
# Data for AL in 2003 already downloaded. Skipping.
# Data for AL in 2004 already downloaded. Skipping.
# Data for AL in 2005 already downloaded. Skipping.
# Data for AL in 2006 already downloaded. Skipping.
# Data for AL in 2007 already downloaded. Skipping.
# Data for AL in 2008 already downloaded. Skipping.
# Data for AL in 2009 already downloaded. Skipping.
# Data for AL in 2010 already downloaded. Skipping.
# Data for AL in 2011 already downloaded. Skipping.
# Data for AL in 2012 already downloaded. Skipping.
# Data for AL in 2013 already downloaded. Skipping.
# Data for AL in 2014 already downloaded. Skipping.
# Data for AL in 2015 already downloaded. Skipping.
# Data for AL in 2016 already downloaded. Skipping.
# Data for AL in 2017 already downloaded. Skipping.
# Data for AL in 2018 already downloaded. Skipping.
# Data for AL in 2019 already downloaded. Skipping.
# Data for AL in 2020 already downloaded. Skipping.
# Data for AK in 2000 already downloaded. Skipping.
# Data for AK in 2001 already downloaded. Skipping.
# Data for AK in 2002 already downloaded. Skipping.
# Data for AK in 2003 already downloaded. Skipping.
# Data for AK in 2004 already downloaded. Skipping.
# Data for AK in 2005 already downloaded. Skipping.
# Data for AK in 2006 already downloaded. Skipping.
# Data for AK in 2007 already downloaded. Skipping.
# Data for AK in 2008 already downloaded. Skipping.
# Data for AK in 2009 already downloaded. Skipping.
# Data for AK in 2010 already downloaded. Skipping.
# Data for AK in 2011 already downloaded. Skipping.
# Data for AK in 2012 already downloaded. Skipping.
# Data for AK in 2013 already downloaded. Skipping.
# Data for AK in 2014 already downloaded. Skipping.
# Data for AK in 2015 already downloaded. Skipping.
# Data for AK in 2016 already downloaded. Skipping.
# Data for AK in 2017 already downloaded. Skipping.
# Data for AK in 2018 already downloaded. Skipping.
# Data for AK in 2019 already downloaded. Skipping.
# Data for AK in 2020 already downloaded. Skipping.
# Data for AZ in 2000 already downloaded. Skipping.
# Data for AZ in 2001 already downloaded. Skipping.
# Data for AZ in 2002 already downloaded. Skipping.
# Data for AZ in 2003 already downloaded. Skipping.
# Data for AZ in 2004 already downloaded. Skipping.
# Data for AZ in 2005 already downloaded. Skipping.
# Data for AZ in 2006 already downloaded. Skipping.
# Data for AZ in 2007 already downloaded. Skipping.
# Data for AZ in 2008 already downloaded. Skipping.
# Data for AZ in 2009 already downloaded. Skipping.
# Data for AZ in 2010 already downloaded. Skipping.
# Data for AZ in 2011 already downloaded. Skipping.
# Data for AZ in 2012 already downloaded. Skipping.
# Data for AZ in 2013 already downloaded. Skipping.
# Data for AZ in 2014 already downloaded. Skipping.
# Data for AZ in 2015 already downloaded. Skipping.
# Data for AZ in 2016 already downloaded. Skipping.
# Data for AZ in 2017 already downloaded. Skipping.
# Data for AZ in 2018 already downloaded. Skipping.
# Data for AZ in 2019 already downloaded. Skipping.
# Data for AZ in 2020 already downloaded. Skipping.
# Data for AR in 2000 already downloaded. Skipping.
# Data for AR in 2001 already downloaded. Skipping.
# Data for AR in 2002 already downloaded. Skipping.
# Data for AR in 2003 already downloaded. Skipping.
# Data for AR in 2004 already downloaded. Skipping.
# Data for AR in 2005 already downloaded. Skipping.
# Data for AR in 2006 already downloaded. Skipping.
# Data for AR in 2007 already downloaded. Skipping.
# Data for AR in 2008 already downloaded. Skipping.
# Data for AR in 2009 already downloaded. Skipping.
# Data for AR in 2010 already downloaded. Skipping.
# Data for AR in 2011 already downloaded. Skipping.
# Data for AR in 2012 already downloaded. Skipping.
# Data for AR in 2013 already downloaded. Skipping.
# Data for AR in 2014 already downloaded. Skipping.
# Data for AR in 2015 already downloaded. Skipping.
# Data for AR in 2016 already downloaded. Skipping.
# Data for AR in 2017 already downloaded. Skipping.
# Data for AR in 2018 already downloaded. Skipping.
# Data for AR in 2019 already downloaded. Skipping.
# Data for AR in 2020 already downloaded. Skipping.
# Data for CA in 2000 already downloaded. Skipping.
# Data for CA in 2001 already downloaded. Skipping.
# Data for CA in 2002 already downloaded. Skipping.
# Data for CA in 2003 already downloaded. Skipping.
# Data for CA in 2004 already downloaded. Skipping.
# Data for CA in 2005 already downloaded. Skipping.
# Data for CA in 2006 already downloaded. Skipping.
# Data for CA in 2007 already downloaded. Skipping.
# Data for CA in 2008 already downloaded. Skipping.
# Data for CA in 2009 already downloaded. Skipping.
# Data for CA in 2010 already downloaded. Skipping.
# Data for CA in 2011 already downloaded. Skipping.
# Data for CA in 2012 already downloaded. Skipping.
# Data for CA in 2013 already downloaded. Skipping.
# Data for CA in 2014 already downloaded. Skipping.
# Data for CA in 2015 already downloaded. Skipping.
# Data for CA in 2016 already downloaded. Skipping.
# Data for CA in 2017 already downloaded. Skipping.
# Data for CA in 2018 already downloaded. Skipping.
# Data for CA in 2019 already downloaded. Skipping.
# Data for CA in 2020 already downloaded. Skipping.
# Data for CO in 2000 already downloaded. Skipping.
# Data for CO in 2001 already downloaded. Skipping.
# Data for CO in 2002 already downloaded. Skipping.
# Data for CO in 2003 already downloaded. Skipping.
# Data for CO in 2004 already downloaded. Skipping.
# Data for CO in 2005 already downloaded. Skipping.
# Data for CO in 2006 already downloaded. Skipping.
# Data for CO in 2007 already downloaded. Skipping.
# Data for CO in 2008 already downloaded. Skipping.
# Data for CO in 2009 already downloaded. Skipping.
# Data for CO in 2010 already downloaded. Skipping.
# Data for CO in 2011 already downloaded. Skipping.
# Data for CO in 2012 already downloaded. Skipping.
# Data for CO in 2013 already downloaded. Skipping.
# Data for CO in 2014 already downloaded. Skipping.
# Data for CO in 2015 already downloaded. Skipping.
# Data for CO in 2016 already downloaded. Skipping.
# Data for CO in 2017 already downloaded. Skipping.
# Data for CO in 2018 already downloaded. Skipping.
# Data for CO in 2019 already downloaded. Skipping.
# Data for CO in 2020 already downloaded. Skipping.
# Data for CT in 2000 already downloaded. Skipping.
# Data for CT in 2001 already downloaded. Skipping.
# Data for CT in 2002 already downloaded. Skipping.
# Data for CT in 2003 already downloaded. Skipping.
# Data for CT in 2004 already downloaded. Skipping.
# Data for CT in 2005 already downloaded. Skipping.
# Data for CT in 2006 already downloaded. Skipping.
# Data for CT in 2007 already downloaded. Skipping.
# Data for CT in 2008 already downloaded. Skipping.
# Data for CT in 2009 already downloaded. Skipping.
# Data for CT in 2010 already downloaded. Skipping.
# Data for CT in 2011 already downloaded. Skipping.
# Data for CT in 2012 already downloaded. Skipping.
# Data for CT in 2013 already downloaded. Skipping.
# Data for CT in 2014 already downloaded. Skipping.
# Data for CT in 2015 already downloaded. Skipping.
# Data for CT in 2016 already downloaded. Skipping.
# Data for CT in 2017 already downloaded. Skipping.
# Data for CT in 2018 already downloaded. Skipping.
# Data for CT in 2019 already downloaded. Skipping.
# Data for CT in 2020 already downloaded. Skipping.
# Data for DE in 2000 already downloaded. Skipping.
# Data for DE in 2001 already downloaded. Skipping.
# Data for DE in 2002 already downloaded. Skipping.
# Data for DE in 2003 already downloaded. Skipping.
# Data for DE in 2004 already downloaded. Skipping.
# Data for DE in 2005 already downloaded. Skipping.
# Data for DE in 2006 already downloaded. Skipping.
# Data for DE in 2007 already downloaded. Skipping.
# Data for DE in 2008 already downloaded. Skipping.
# Data for DE in 2009 already downloaded. Skipping.
# Data for DE in 2010 already downloaded. Skipping.
# Data for DE in 2011 already downloaded. Skipping.
# Data for DE in 2012 already downloaded. Skipping.
# Data for DE in 2013 already downloaded. Skipping.
# Data for DE in 2014 already downloaded. Skipping.
# Data for DE in 2015 already downloaded. Skipping.
# Data for DE in 2016 already downloaded. Skipping.
# Data for DE in 2017 already downloaded. Skipping.
# Data for DE in 2018 already downloaded. Skipping.
# Data for DE in 2019 already downloaded. Skipping.
# Data for DE in 2020 already downloaded. Skipping.
# Data for FL in 2000 already downloaded. Skipping.
# Data for FL in 2001 already downloaded. Skipping.
# Data for FL in 2002 already downloaded. Skipping.
# Data for FL in 2003 already downloaded. Skipping.
# Data for FL in 2004 already downloaded. Skipping.
# Data for FL in 2005 already downloaded. Skipping.
# Data for FL in 2006 already downloaded. Skipping.
# Data for FL in 2007 already downloaded. Skipping.
# Data for FL in 2008 already downloaded. Skipping.
# Data for FL in 2009 already downloaded. Skipping.
# Data for FL in 2010 already downloaded. Skipping.
# Data for FL in 2011 already downloaded. Skipping.
# Data for FL in 2012 already downloaded. Skipping.
# Data for FL in 2013 already downloaded. Skipping.
# Data for FL in 2014 already downloaded. Skipping.
# Data for FL in 2015 already downloaded. Skipping.
# Data for FL in 2016 already downloaded. Skipping.
# Data for FL in 2017 already downloaded. Skipping.
# Data for FL in 2018 already downloaded. Skipping.
# Data for FL in 2019 already downloaded. Skipping.
# Data for FL in 2020 already downloaded. Skipping.
# Data for GA in 2000 already downloaded. Skipping.
# Data for GA in 2001 already downloaded. Skipping.
# Data for GA in 2002 already downloaded. Skipping.
# Data for GA in 2003 already downloaded. Skipping.
# Data for GA in 2004 already downloaded. Skipping.
# Data for GA in 2005 already downloaded. Skipping.
# Data for GA in 2006 already downloaded. Skipping.
# Data for GA in 2007 already downloaded. Skipping.
# Data for GA in 2008 already downloaded. Skipping.
# Data for GA in 2009 already downloaded. Skipping.
# Data for GA in 2010 already downloaded. Skipping.
# Data for GA in 2011 already downloaded. Skipping.
# Data for GA in 2012 already downloaded. Skipping.
# Data for GA in 2013 already downloaded. Skipping.
# Data for GA in 2014 already downloaded. Skipping.
# Data for GA in 2015 already downloaded. Skipping.
# Data for GA in 2016 already downloaded. Skipping.
# Data for GA in 2017 already downloaded. Skipping.
# Data for GA in 2018 already downloaded. Skipping.
# Data for GA in 2019 already downloaded. Skipping.
# Data for GA in 2020 already downloaded. Skipping.
# Data for HI in 2000 already downloaded. Skipping.
# Data for HI in 2001 already downloaded. Skipping.
# Data for HI in 2002 already downloaded. Skipping.
# Data for HI in 2003 already downloaded. Skipping.
# Data for HI in 2004 already downloaded. Skipping.
# Data for HI in 2005 already downloaded. Skipping.
# Data for HI in 2006 already downloaded. Skipping.
# Data for HI in 2007 already downloaded. Skipping.
# Data for HI in 2008 already downloaded. Skipping.
# Data for HI in 2009 already downloaded. Skipping.
# Data for HI in 2010 already downloaded. Skipping.
# Data for HI in 2011 already downloaded. Skipping.
# Data for HI in 2012 already downloaded. Skipping.
# Data for HI in 2013 already downloaded. Skipping.
# Data for HI in 2014 already downloaded. Skipping.
# Data for HI in 2015 already downloaded. Skipping.
# Data for HI in 2016 already downloaded. Skipping.
# Data for HI in 2017 already downloaded. Skipping.
# Data for HI in 2018 already downloaded. Skipping.
# Data for HI in 2019 already downloaded. Skipping.
# Data for HI in 2020 already downloaded. Skipping.
# Data for ID in 2000 already downloaded. Skipping.
# Data for ID in 2001 already downloaded. Skipping.
# Data for ID in 2002 already downloaded. Skipping.
# Data for ID in 2003 already downloaded. Skipping.
# Data for ID in 2004 already downloaded. Skipping.
# Data for ID in 2005 already downloaded. Skipping.
# Data for ID in 2006 already downloaded. Skipping.
# Data for ID in 2007 already downloaded. Skipping.
# Data for ID in 2008 already downloaded. Skipping.
# Data for ID in 2009 already downloaded. Skipping.
# Data for ID in 2010 already downloaded. Skipping.
# Data for ID in 2011 already downloaded. Skipping.
# Data for ID in 2012 already downloaded. Skipping.
# Data for ID in 2013 already downloaded. Skipping.
# Data for ID in 2014 already downloaded. Skipping.
# Data for ID in 2015 already downloaded. Skipping.
# Data for ID in 2016 already downloaded. Skipping.
# Data for ID in 2017 already downloaded. Skipping.
# Data for ID in 2018 already downloaded. Skipping.
# Data for ID in 2019 already downloaded. Skipping.
# Data for ID in 2020 already downloaded. Skipping.
# Data for IL in 2000 already downloaded. Skipping.
# Data for IL in 2001 already downloaded. Skipping.
# Data for IL in 2002 already downloaded. Skipping.
# Data for IL in 2003 already downloaded. Skipping.
# Data for IL in 2004 already downloaded. Skipping.
# Data for IL in 2005 already downloaded. Skipping.
# Data for IL in 2006 already downloaded. Skipping.
# Data for IL in 2007 already downloaded. Skipping.
# Data for IL in 2008 already downloaded. Skipping.
# Data for IL in 2009 already downloaded. Skipping.
# Data for IL in 2010 already downloaded. Skipping.
# Data for IL in 2011 already downloaded. Skipping.
# Data for IL in 2012 already downloaded. Skipping.
# Data for IL in 2013 already downloaded. Skipping.
# Data for IL in 2014 already downloaded. Skipping.
# Data for IL in 2015 already downloaded. Skipping.
# Data for IL in 2016 already downloaded. Skipping.
# Data for IL in 2017 already downloaded. Skipping.
# Data for IL in 2018 already downloaded. Skipping.
# Data for IL in 2019 already downloaded. Skipping.
# Data for IL in 2020 already downloaded. Skipping.
# Data for IN in 2000 already downloaded. Skipping.
# Data for IN in 2001 already downloaded. Skipping.
# Data for IN in 2002 already downloaded. Skipping.
# Data for IN in 2003 already downloaded. Skipping.
# Data for IN in 2004 already downloaded. Skipping.
# Data for IN in 2005 already downloaded. Skipping.
# Data for IN in 2006 already downloaded. Skipping.
# Data for IN in 2007 already downloaded. Skipping.
# Data for IN in 2008 already downloaded. Skipping.
# Data for IN in 2009 already downloaded. Skipping.
# Data for IN in 2010 already downloaded. Skipping.
# Data for IN in 2011 already downloaded. Skipping.
# Data for IN in 2012 already downloaded. Skipping.
# Data for IN in 2013 already downloaded. Skipping.
# Data for IN in 2014 already downloaded. Skipping.
# Data for IN in 2015 already downloaded. Skipping.
# Data for IN in 2016 already downloaded. Skipping.
# Data for IN in 2017 already downloaded. Skipping.
# Data for IN in 2018 already downloaded. Skipping.
# Data for IN in 2019 already downloaded. Skipping.
# Data for IN in 2020 already downloaded. Skipping.
# Data for IA in 2000 already downloaded. Skipping.
# Data for IA in 2001 already downloaded. Skipping.
# Data for IA in 2002 already downloaded. Skipping.
# Data for IA in 2003 already downloaded. Skipping.
# Data for IA in 2004 already downloaded. Skipping.
# Data for IA in 2005 already downloaded. Skipping.
# Data for IA in 2006 already downloaded. Skipping.
# Data for IA in 2007 already downloaded. Skipping.
# Data for IA in 2008 already downloaded. Skipping.
# Data for IA in 2009 already downloaded. Skipping.
# Data for IA in 2010 already downloaded. Skipping.
# Data for IA in 2011 already downloaded. Skipping.
# Data for IA in 2012 already downloaded. Skipping.
# Data for IA in 2013 already downloaded. Skipping.
# Data for IA in 2014 already downloaded. Skipping.
# Data for IA in 2015 already downloaded. Skipping.
# Data for IA in 2016 already downloaded. Skipping.
# Data for IA in 2017 already downloaded. Skipping.
# Data for IA in 2018 already downloaded. Skipping.
# Data for IA in 2019 already downloaded. Skipping.
# Data for IA in 2020 already downloaded. Skipping.
# Data for KS in 2000 already downloaded. Skipping.
# Data for KS in 2001 already downloaded. Skipping.
# Data for KS in 2002 already downloaded. Skipping.
# Data for KS in 2003 already downloaded. Skipping.
# Data for KS in 2004 already downloaded. Skipping.
# Data for KS in 2005 already downloaded. Skipping.
# Data for KS in 2006 already downloaded. Skipping.
# Data for KS in 2007 already downloaded. Skipping.
# Data for KS in 2008 already downloaded. Skipping.
# Data for KS in 2009 already downloaded. Skipping.
# Data for KS in 2010 already downloaded. Skipping.
# Data for KS in 2011 already downloaded. Skipping.
# Data for KS in 2012 already downloaded. Skipping.
# Data for KS in 2013 already downloaded. Skipping.
# Data for KS in 2014 already downloaded. Skipping.
# Data for KS in 2015 already downloaded. Skipping.
# Data for KS in 2016 already downloaded. Skipping.
# Data for KS in 2017 already downloaded. Skipping.
# Data for KS in 2018 already downloaded. Skipping.
# Data for KS in 2019 already downloaded. Skipping.
# Data for KS in 2020 already downloaded. Skipping.
# Data for KY in 2000 already downloaded. Skipping.
# Data for KY in 2001 already downloaded. Skipping.
# Data for KY in 2002 already downloaded. Skipping.
# Data for KY in 2003 already downloaded. Skipping.
# Data for KY in 2004 already downloaded. Skipping.
# Data for KY in 2005 already downloaded. Skipping.
# Data for KY in 2006 already downloaded. Skipping.
# Data for KY in 2007 already downloaded. Skipping.
# Data for KY in 2008 already downloaded. Skipping.
# Data for KY in 2009 already downloaded. Skipping.
# Data for KY in 2010 already downloaded. Skipping.
# Data for KY in 2011 already downloaded. Skipping.
# Data for KY in 2012 already downloaded. Skipping.
# Data for KY in 2013 already downloaded. Skipping.
# Data for KY in 2014 already downloaded. Skipping.
# Data for KY in 2015 already downloaded. Skipping.
# Data for KY in 2016 already downloaded. Skipping.
# Data for KY in 2017 already downloaded. Skipping.
# Data for KY in 2018 already downloaded. Skipping.
# Data for KY in 2019 already downloaded. Skipping.
# Data for KY in 2020 already downloaded. Skipping.
# Failed to download data for LA in 2000: HTTP Error 404: Not Found
# Failed to download data for LA in 2001: HTTP Error 404: Not Found
# Failed to download data for LA in 2002: HTTP Error 404: Not Found
# Failed to download data for LA in 2003: HTTP Error 404: Not Found
# Failed to download data for LA in 2004: HTTP Error 404: Not Found
# Failed to download data for LA in 2005: HTTP Error 404: Not Found
# Failed to download data for LA in 2006: HTTP Error 404: Not Found
# Failed to download data for ND in 2000: HTTP Error 404: Not Found
# Data for TN in 2000 already downloaded. Skipping.
# Data for TN in 2001 already downloaded. Skipping.
# Data for TN in 2002 already downloaded. Skipping.
# Data for TN in 2003 already downloaded. Skipping.
# Data for TN in 2004 already downloaded. Skipping.
# Data for TN in 2005 already downloaded. Skipping.
# Data for TN in 2006 already downloaded. Skipping.
# Data for TN in 2007 already downloaded. Skipping.
# Data for TN in 2008 already downloaded. Skipping.
# Data for TN in 2009 already downloaded. Skipping.
# Data for TN in 2010 already downloaded. Skipping.
# Data for TN in 2011 already downloaded. Skipping.
# Data for TN in 2012 already downloaded. Skipping.
# Data for TN in 2013 already downloaded. Skipping.
# Data for TN in 2014 already downloaded. Skipping.
# Data for TN in 2015 already downloaded. Skipping.
# Data for TN in 2016 already downloaded. Skipping.
# Data for TN in 2017 already downloaded. Skipping.
# Data for TN in 2018 already downloaded. Skipping.
# Data for TN in 2019 already downloaded. Skipping.
# Data for TN in 2020 already downloaded. Skipping.
# Site retrieval and storage is complete for all states.
